# %%
# Imports
import numpy as np
import pandas as pd
import joblib
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from scipy.sparse import load_npz, hstack, csr_matrix

# %%
# Paths
BASE_DIR = r"C:\Users\apara\Desktop\MDM\saved_models"
BERT_DIR = r"C:\Users\apara\Desktop\MDM\saved_models\distilBERT_4_epochs"
FEATURES_PATH = f"{BASE_DIR}\\extracted_features.csv"
LABEL_ENCODER_PATH = f"{BASE_DIR}\\label_encoder.pkl"
X_TEST_TFIDF_PATH = f"{BASE_DIR}\\X_test_tfidf.npz"
TRAIN_CSV_PATH = r"C:\Users\apara\Desktop\MDM\train_none.csv"

MODELS = ["cohere-chat", "gpt4", "mistral-chat", "mpt-chat", "llama-chat"]
RANDOM_STATE = 5

# Label encoder
le = joblib.load(LABEL_ENCODER_PATH)
print(f"Classes: {list(le.classes_)}")

# Load test labels
features_df = pd.read_csv(FEATURES_PATH)
test_labels = features_df[features_df['split'] == 'test']['label']
y_test = le.transform(test_labels)

# Load test texts
train_df = pd.read_csv(TRAIN_CSV_PATH)
_, test_df = train_test_split(train_df, test_size=0.2, random_state=RANDOM_STATE, stratify=train_df["model"])
test_df = test_df[test_df["model"].isin(MODELS)]
test_texts = test_df["generation"].astype(str).reset_index(drop=True)

# Load TF-IDF and features for ML models
test_features = features_df[features_df['split'] == 'test'].drop(['label', 'split'], axis=1)
X_test_tfidf = load_npz(X_TEST_TFIDF_PATH)
X_test_num = csr_matrix(test_features.values)
X_test = hstack([X_test_tfidf, X_test_num], format='csr')

# Load ML models
rf_model = joblib.load(f"{BASE_DIR}\\random_forest.pkl")
xgb_model = joblib.load(f"{BASE_DIR}\\xgboost.pkl")
lgb_model = joblib.load(f"{BASE_DIR}\\lightgbm.pkl")

# Get ML predictions and probabilities
rf_preds = rf_model.predict(X_test)
rf_probs = rf_model.predict_proba(X_test)
xgb_preds = xgb_model.predict(X_test)
xgb_probs = xgb_model.predict_proba(X_test)
lgb_preds = lgb_model.predict(X_test)
lgb_probs = lgb_model.predict_proba(X_test)

# Load DistilBERT predictions
bert_preds = np.load(f"{BERT_DIR}\\bert_preds.npy")
bert_probs = np.load(f"{BERT_DIR}\\bert_probs.npy")

print(f"Loaded {len(y_test)} test samples")

# Create Stacking Ensemble predictions
model_names = ['RandomForest', 'XGBoost', 'LightGBM', 'DistilBERT']
probabilities = {
    'RandomForest': rf_probs,
    'XGBoost': xgb_probs,
    'LightGBM': lgb_probs,
    'DistilBERT': bert_probs
}
predictions = {
    'RandomForest': rf_preds,
    'XGBoost': xgb_preds,
    'LightGBM': lgb_preds,
    'DistilBERT': bert_preds
}

# Create stacking meta-features
meta_features = np.hstack([probabilities[m] for m in model_names])

# Train stacking with cross-validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)
stacking_preds = np.zeros(len(y_test))

for train_idx, val_idx in skf.split(meta_features, y_test):
    X_meta_train = meta_features[train_idx]
    y_meta_train = y_test[train_idx]
    X_meta_val = meta_features[val_idx]
    
    meta_clf = LogisticRegression(max_iter=1000, random_state=RANDOM_STATE)
    meta_clf.fit(X_meta_train, y_meta_train)
    stacking_preds[val_idx] = meta_clf.predict(X_meta_val)

stacking_preds = stacking_preds.astype(int)
print(f"Stacking Accuracy: {accuracy_score(y_test, stacking_preds):.4f}")

# Print 20 random samples
np.random.seed(42)
sample_indices = np.random.choice(len(y_test), size=20, replace=False)

for idx in sample_indices:
    text = test_texts.iloc[idx]
    ground_truth = le.classes_[y_test[idx]]
    
    distilbert_pred = le.classes_[bert_preds[idx]]
    lgb_pred = le.classes_[lgb_preds[idx]]
    xgb_pred = le.classes_[xgb_preds[idx]]
    rf_pred = le.classes_[rf_preds[idx]]
    stack_pred = le.classes_[stacking_preds[idx]]
    
    # Truncate text for display
    display_text = text[:500] + "..." if len(text) > 500 else text
    
    print("=" * 70)
    print(f"\n{display_text}\n")
    print("-" * 70)
    print(f"Ground Truth: {ground_truth}")
    print("-" * 70)
    print(f"{'Model':<25} {'Prediction':<20} {'Correct?':<10}")
    print("-" * 70)
    print(f"{'DistilBERT:':<25} {distilbert_pred:<20} | {'Y' if distilbert_pred == ground_truth else 'N'}")
    print(f"{'LightGBM:':<25} {lgb_pred:<20} | {'Y' if lgb_pred == ground_truth else 'N'}")
    print(f"{'XGBoost:':<25} {xgb_pred:<20} | {'Y' if xgb_pred == ground_truth else 'N'}")
    print(f"{'Random Forest:':<25} {rf_pred:<20} | {'Y' if rf_pred == ground_truth else 'N'}")
    print(f"{'Stacking Ensemble:':<25} {stack_pred:<20} | {'Y' if stack_pred == ground_truth else 'N'}")
    print("\n")
# Out:
# c:\Users\apara\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Classes: ['cohere-chat', 'gpt4', 'llama-chat', 'mistral-chat', 'mpt-chat']
# c:\Users\apara\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\apara\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator RandomForestClassifier from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\apara\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\apara\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\apara\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# Loaded 42787 test samples
# Stacking Accuracy: 0.9178
# ======================================================================
#
# Ingredients:
# - 1 cup granulated sugar
# - 1 cup water
# - 1 (14 oz) can sweetened condensed milk
# - 4 large eggs
# - 2 tsp vanilla extract
# - 1/4 cup caramel sauce
#
# Instructions:
#
# 1. Preheat the oven to 325°F.
#
# 2. In a medium saucepan, combine sugar and water. Cook over medium heat, stirring occasionally, until the sugar dissolves. Increase heat to high and bring to a boil. Cook for about 10-15 minutes, until the mixture turns into a golden brown color. Remove from heat and let it cool.
#
# 3. In a mixing ...
#
# ----------------------------------------------------------------------
# Ground Truth: mpt-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               mpt-chat             | Y
# LightGBM:                 mpt-chat             | Y
# XGBoost:                  mpt-chat             | Y
# Random Forest:            mpt-chat             | Y
# Stacking Ensemble:        mpt-chat             | Y
#
#
# ======================================================================
#
# I've come to understand that my self-esteem issues stem from childhood experiences where I was constantly compared to others and never felt good enough. These feelings were reinforced by critical comments from family members and peers, leading me to believe that I wasn't worthy of love or acceptance. It's taken time and therapy for me to realize that these beliefs are untrue and that I deserve happiness and self-love just as much as anyone else. While it's still a work in progress, recognizing t...
#
# ----------------------------------------------------------------------
# Ground Truth: mpt-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               mpt-chat             | Y
# LightGBM:                 mpt-chat             | Y
# XGBoost:                  mpt-chat             | Y
# Random Forest:            mpt-chat             | Y
# Stacking Ensemble:        mpt-chat             | Y
#
#
# ======================================================================
#
# Colbie Caillat is an American singer-songwriter and musician from Malibu, California. She rose to fame in the mid-2000s with her debut album, Coco, which included the hit singles "Bubbly" and "Realize."
#
# Early Life and Career
#
# Caillat was born on May 28, 1985, in Malibu, California. She grew up in a musical family and began singing at a young age. She attended Malibu High School, where she met her future collaborator, Jason Reeves. After high school, Caillat and Reeves began performing together ...
#
# ----------------------------------------------------------------------
# Ground Truth: llama-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               llama-chat           | Y
# LightGBM:                 llama-chat           | Y
# XGBoost:                  llama-chat           | Y
# Random Forest:            llama-chat           | Y
# Stacking Ensemble:        llama-chat           | Y
#
#
# ======================================================================
#
# The story follows the journey of a young woman named Sarah, who has just moved to a small coastal town in Maine to escape her complicated past. She takes up residence in a tiny cottage on the outskirts of town, surrounded by dense woods and rugged shoreline. As she settles into her new life, Sarah becomes fascinated with the local legend of the pointed firs, a group of ancient trees that are said to possess mystical powers.
#
# Despite initial resistance from the tight-knit community, Sarah befrien...
#
# ----------------------------------------------------------------------
# Ground Truth: llama-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               llama-chat           | Y
# LightGBM:                 llama-chat           | Y
# XGBoost:                  llama-chat           | Y
# Random Forest:            llama-chat           | Y
# Stacking Ensemble:        llama-chat           | Y
#
#
# ======================================================================
#
# In the mystical land of Annwn, where the veil between the mortal world and the realm of faerie is thin, a young man named Eira is struggling to come to terms with her identity as the future ruler of the faerie kingdom. Eira's mother, the powerful Queen Morwen, has ruled Annwn with an iron fist for centuries, keeping its inhabitants in line through fear and intimidation. But Eira has always felt stifled by his mother's strict rules and harsh methods, yearning for a more peaceful and just way of g...
#
# ----------------------------------------------------------------------
# Ground Truth: llama-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               llama-chat           | Y
# LightGBM:                 llama-chat           | Y
# XGBoost:                  llama-chat           | Y
# Random Forest:            llama-chat           | Y
# Stacking Ensemble:        llama-chat           | Y
#
#
# ======================================================================
#
# She fluttered through a world of change
# And learned from every shifting stage
# From every smile and frown
# She gathered all her strength
#
# She grew resilient, tough, and wise
# Learning from mistakes and missteps
# Never backing down from a challenge
# Three years spent flourishing and thriving
#
# She is a strong and spirited soul
# Ready to take on whatever comes next
# She will shine through and overcome
# Three years she grew in sun and shower
#
# ----------------------------------------------------------------------
# Ground Truth: cohere-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               cohere-chat          | Y
# LightGBM:                 cohere-chat          | Y
# XGBoost:                  cohere-chat          | Y
# Random Forest:            cohere-chat          | Y
# Stacking Ensemble:        cohere-chat          | Y
#
#
# ======================================================================
#
# In a recent survey conducted by a leading market research firm, it was found that a majority of voters in the country do not trust politicians. The survey, which interviewed a random sample of 1,000 adults, asked participants whether they trusted politicians to do what is right for the country. A staggering 80% of respondents said they did not trust politicians, while only 20% said they did.
#
# When asked to explain their reasons for lack of trust, many participants cited corruption, dishonesty, a...
#
# ----------------------------------------------------------------------
# Ground Truth: mpt-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               mpt-chat             | Y
# LightGBM:                 mpt-chat             | Y
# XGBoost:                  mpt-chat             | Y
# Random Forest:            mpt-chat             | Y
# Stacking Ensemble:        mpt-chat             | Y
#
#
# ======================================================================
#
# Jose Mourinho, former manager of Manchester United and Chelsea, has revealed his plans to return to top-level management, with a focus on sustainable success rather than short-term fixes.
#
# In an exclusive interview with the BBC, Mourinho discussed his time away from the game, spent reflecting on his past mistakes and identifying areas for improvement.
#
# "I've had time to think about my approach, and I realise now that I was too focused on immediate results," he said. "I want to build a team that ...
#
# ----------------------------------------------------------------------
# Ground Truth: llama-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               llama-chat           | Y
# LightGBM:                 llama-chat           | Y
# XGBoost:                  llama-chat           | Y
# Random Forest:            llama-chat           | Y
# Stacking Ensemble:        llama-chat           | Y
#
#
# ======================================================================
#
# Paul Tergat, the 1998 New York City Marathon champion, has confirmed that Julius Chepkemei will join the Edinburgh roster for the upcoming season. Chepkemei, who has a personal best time of 2:06:20, will be looking to make an immediate impact in the Scottish capital.
#
# "We are delighted to have Chepkemei on board," Tergat said. "He is a highly talented athlete with a lot of experience, and I believe he will be a valuable addition to our team."
#
# Chepkemei, who has represented Kenya in multiple int...
#
# ----------------------------------------------------------------------
# Ground Truth: mpt-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               mpt-chat             | Y
# LightGBM:                 mpt-chat             | Y
# XGBoost:                  mpt-chat             | Y
# Random Forest:            mpt-chat             | Y
# Stacking Ensemble:        mpt-chat             | Y
#
#
# ======================================================================
#
# Steve Jobs, the co-founder and former CEO of Apple Inc., has passed away at the age of 56 after a long battle with pancreatic cancer. Jobs was instrumental in developing many of Apple's most successful products, including the iPod, iPhone, and iPad. However, it is his role in creating the first Apple Mac that has earned him a place in history as one of the greatest innovators of our time. The Macintosh, which debuted in 1984, revolutionized personal computing and set the stage for the technologi...
#
# ----------------------------------------------------------------------
# Ground Truth: mpt-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               mpt-chat             | Y
# LightGBM:                 mpt-chat             | Y
# XGBoost:                  mpt-chat             | Y
# Random Forest:            mpt-chat             | Y
# Stacking Ensemble:        mpt-chat             | Y
#
#
# ======================================================================
#
# British actor and comedian Stephen Fry is set to lend his voice to the upcoming adaptation of Douglas Adams' cult classic, "The Hitchhiker's Guide to the Galaxy". The announcement was made by Hulu, the streaming service producing the series, which is expected to premiere in 2022.
#
# Fry, known for his roles in "Blackadder" and "Jeeves and Wooster", will be voicing the character of 'The Guide', an electronic book that provides advice and information to intergalactic travellers. The character was pr...
#
# ----------------------------------------------------------------------
# Ground Truth: gpt4
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               gpt4                 | Y
# LightGBM:                 gpt4                 | Y
# XGBoost:                  gpt4                 | Y
# Random Forest:            llama-chat           | N
# Stacking Ensemble:        gpt4                 | Y
#
#
# ======================================================================
#
# Hey fellow Redditors,
#
# I'm not sure if this is a thing, but I think I might be experiencing withdrawal symptoms from not having hot drinks. I know it sounds a bit strange, but hear me out.
#
# Lately, I've been noticing that when I don't have a hot drink in the morning, I feel completely off. My mind feels foggy, I can't concentrate, and I just feel like something is missing. It's like my soul is empty or something.
#
# Now, I know what you're thinking - maybe I'm just not getting enough caffeine. But...
#
# ----------------------------------------------------------------------
# Ground Truth: llama-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               llama-chat           | Y
# LightGBM:                 llama-chat           | Y
# XGBoost:                  llama-chat           | Y
# Random Forest:            llama-chat           | Y
# Stacking Ensemble:        llama-chat           | Y
#
#
# ======================================================================
#
# "Jackie Brown" is a gripping crime drama that keeps you on the edge of your seat from start to finish. The movie boasts an all-star cast, with Pam Grier stealing the show as the titular character. The storyline is engaging, and the characters are well-developed and relatable. The pacing is perfect, and the film never feels slow or draggy. The action scenes are intense and well-choreographed, and the dialogue is sharp and witty. "Jackie Brown" is a cinematic masterpiece that is not to be missed.
#
# ----------------------------------------------------------------------
# Ground Truth: mpt-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               mpt-chat             | Y
# LightGBM:                 mpt-chat             | Y
# XGBoost:                  mpt-chat             | Y
# Random Forest:            mpt-chat             | Y
# Stacking Ensemble:        mpt-chat             | Y
#
#
# ======================================================================
#
# Jitendra Awhad is a notable Indian politician who has served as a Member of the Legislative Assembly (MLA) in the Gujarat Legislative Assembly. He represents the Bavisatta constituency, which is located in the Anand district of Gujarat. Awhad is a member of the Bharatiya Janata Party (BJP) and has held various positions within the party, including vice-president of the BJP's Gujarat unit.
#
# Awhad first entered politics in 2005 when he was elected as an MLA for the first time. He was re-elected in...
#
# ----------------------------------------------------------------------
# Ground Truth: mpt-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               mpt-chat             | Y
# LightGBM:                 mpt-chat             | Y
# XGBoost:                  mpt-chat             | Y
# Random Forest:            mpt-chat             | Y
# Stacking Ensemble:        mpt-chat             | Y
#
#
# ======================================================================
#
# The Bishop of Bermuda is an episcopal figurehead of the Anglican Church of Bermuda. Bermuda is the earliest and most populous remaining British Overseas Territory, and the Bishop of Bermuda essentially presides over the Anglican faith on the islands. The position of the Bishop falls under the overall purview of the Archbishop of Canterbury, the senior bishop and principal leader of the Church of England, although the bishop carries the primary responsibility for the Anglican community in Bermuda...
#
# ----------------------------------------------------------------------
# Ground Truth: gpt4
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               gpt4                 | Y
# LightGBM:                 gpt4                 | Y
# XGBoost:                  gpt4                 | Y
# Random Forest:            mistral-chat         | N
# Stacking Ensemble:        gpt4                 | Y
#
#
# ======================================================================
#
# This paper presents a comprehensive study on medical image segmentation using a multi-modal Convolutional Neural Network (CNN). The primary focus is on the exploration of various image fusion schemes to enhance the performance of the segmentation process. The study introduces a novel fusion strategy that integrates different modalities at multiple levels of the network, thereby improving the discriminative capability of the model. Experimental results on several public medical imaging datasets d...
#
# ----------------------------------------------------------------------
# Ground Truth: gpt4
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               gpt4                 | Y
# LightGBM:                 gpt4                 | Y
# XGBoost:                  gpt4                 | Y
# Random Forest:            gpt4                 | Y
# Stacking Ensemble:        gpt4                 | Y
#
#
# ======================================================================
#
# Yeah, I've been feeling the same way. I've been playing for a few hours now, and while the game is definitely fun, the combat is starting to feel a bit same-y. I feel like I'm just mashing the same buttons over and over again, and it's getting a bit boring.
#
# I've tried experimenting with different weapons and abilities, but it doesn't seem to make much of a difference. The enemies are all pretty much the same, and the combat encounters feel like they're following the same pattern: walk into a ro...
#
# ----------------------------------------------------------------------
# Ground Truth: llama-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               llama-chat           | Y
# LightGBM:                 llama-chat           | Y
# XGBoost:                  llama-chat           | Y
# Random Forest:            llama-chat           | Y
# Stacking Ensemble:        llama-chat           | Y
#
#
# ======================================================================
#
# Abstract:
# With the rise of deep learning, image segmentation has gained significant attention as a means of extracting meaningful information from images. This paper provides a comprehensive survey of the current state of image segmentation using deep learning techniques. We begin by introducing the concept of image segmentation and its applications in various fields such as medical imaging, autonomous driving, and robotics. We then review the different approaches to image segmentation, includin...
#
# ----------------------------------------------------------------------
# Ground Truth: cohere-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               cohere-chat          | Y
# LightGBM:                 cohere-chat          | Y
# XGBoost:                  cohere-chat          | Y
# Random Forest:            mistral-chat         | N
# Stacking Ensemble:        cohere-chat          | Y
#
#
# ======================================================================
#
# Orecchiette, Sausage and Broccoli Rabe is a delicious Italian dish that combines the flavors of pork sausage, broccoli rabe (a leafy green vegetable), garlic, and chili flakes with the comforting bite of orecchiette pasta. Here's a simple recipe to make this dish at home:
#
# Ingredients:
#
# * 12 oz (340g) orecchiette pasta
# * 6 oz (170g) Italian sweet sausage (such as pork sausage or sopressata), casings removed
# * 2 cloves of garlic, minced
# * 1 head of broccoli rabe (about 1 lb / 450g), ends trimmed,...
#
# ----------------------------------------------------------------------
# Ground Truth: llama-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               llama-chat           | Y
# LightGBM:                 llama-chat           | Y
# XGBoost:                  llama-chat           | Y
# Random Forest:            llama-chat           | Y
# Stacking Ensemble:        llama-chat           | Y
#
#
# ======================================================================
#
# In the mystical land of Krynn, dragons rule the skies and shape the fate of its inhabitants. For centuries, these majestic creatures have been revered as divine beings, capable of bringing both destruction and prosperity with their powerful breaths and magical abilities. But when an ancient prophecy foretells of a great darkness threatening to consume the world, the people of Krynn must band together to protect their realm from certain doom.
#
# As tensions rise between rival factions vying for con...
#
# ----------------------------------------------------------------------
# Ground Truth: mistral-chat
# ----------------------------------------------------------------------
# Model                     Prediction           Correct?
# ----------------------------------------------------------------------
# DistilBERT:               mpt-chat             | N
# LightGBM:                 llama-chat           | N
# XGBoost:                  llama-chat           | N
# Random Forest:            llama-chat           | N
# Stacking Ensemble:        mistral-chat         | Y
